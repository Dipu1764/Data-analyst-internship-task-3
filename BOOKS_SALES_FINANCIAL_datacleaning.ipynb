# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipu1764/Data-analyst-internship-task-3/blob/DATA/BOOKS_SALES_FINANCIAL_datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Books_Data_Clean.csv')

# %%
data.isnull().sum()
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code          53
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
book_data = data.dropna()

# %%
book_data.to_excel("book_data.xlsx", index=False)
